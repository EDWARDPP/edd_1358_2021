# %% [markdown]
# <a href="https://colab.research.google.com/github/EDWARDPP/edd_1358_2021/blob/master/Tarea2_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Array 
"""
class Array:
  def __init__(self, tam):
    self.__datos = [0 for x in range(tam)] #generador que inicializa todo en 0

  def get_item(self, index):
    dato = 0
    if index >= 0 and index <=len(self.__datos): #validaciones
      dato =  self.__datos[index]
    else:
      print("Error en el indice")
    return dato

  def set_item(self, dato, index):
    if index >= 0 and index <=len(self.__datos):
        self.__datos[index] = dato
    else:
      print("Error en el indice")

  def get_Lenght(self):
    return len(self.__datos)

  def clear(self, dato):
    self.__datos = [dato for x in range(tam)]

  def __iter__(self):
    return _getIterator(self.__datos)


class _getIterator: #sirve para iterar sobre una lista de forma simple
  def __init__(self, arreglo):
    self.__arreglo = arreglo
    self.__indice_actual = 0

  def __iter__(self):
    return self

  def __next__(self, ):
    if self.__indice_actual<len(self.__arreglo):
      dato = self.__arreglo[self.__indice_actual]
      self.__indice_actual +=1
      return dato
    else:
      raise StopIteration

# %%
class Empleado:
  def __init__(self, num, nombre, pat, mat, he, sb, anio):
      self.__num_trabajador = num 
      self.__nombres = nombre
      self.__paterno = pat
      self.__materno = mat
      self.__horas_extra = he
      self.__sueldo_base= sb
      self.__anio_ingreso = anio

  def set_num_trabajador(self, num):
    self.__num_trabajador = num
  def get_num_trabajador(self):
    return self.__num_trabajador
  def set_nombres(self, nombre):
    self.__nombres = nombre
  def get_nombre(self):
    return self.__nombres
  def set_paterno(self, pat):
    self.__paterno = pat
  def get_paterno(self):
    return self.__paterno
  def set_materno(self, mat):
    self.__materno = mat
  def get_materno(self):
    return self.__materno
  def set_horas_extra(self, he):
    self.__horas_extra = he
  def get_horas_extra(self):
    return self.__horas_extra
  def set_sueldo_base(self, sb):
    self.__sueldo_base = sb
  def get_sueldo_base(self):
    return self.__sueldo_base
  def set_anio_ingreso(self, anio):
    self.__anio_ingreso = anio
  def get_anio_ingreso(self):
    return self.__anio_ingreso

  
  def calcular_sueldo(self):
    sueldo_base = self.__sueldo_base
    sueldo_horas_extras = (self.__horas_extra*246.5)
    sueldo_antiguedad = (2020-self.__anio_ingreso)*.03
    sueldo_total = (sueldo_base+sueldo_horas_extras+sueldo_antiguedad)
    print(f"El sueldo de: {self.__nombres} {self.__paterno} {self.__materno} es de ${sueldo_total} ")
  


  def to_String(self):
    print(f"Numero de trabajador:{self.__num_trabajador} Nombre:{self.__nombres} Apellido paterno:{self.__paterno} Apellido materno:{self.__materno} Horas extra:{self.__horas_extra} Sueldo base:{self.__sueldo_base} Año de ingreso:{self.__anio_ingreso}")

# %%
"""
ADT sueldos --> encapsula datos de nomina

cargar_datos(ruta_archivo)
calcular_sueldos()
reportar_mayor_ant()
reportar_menor_ant
"""
class Sueldos:
  def __init__(self):
    self.__data = None

  def cargar_datos(self, ruta_archivo):
    archivo = open( ruta_archivo, "rt", encoding='latin1')
    lineas = archivo.readlines()
    archivo.close
    self.data = Array(len(lineas)-1) #tiene los encabezados

    """for linea in lineas:
      print(linea)"""
    #Creando listas separadas para poder operar con sus valores.
    lista1 = lineas[1]
    lista2 = lineas[2]
    lista3 = lineas[3]
    lista4 = lineas[4]
    lista5 = lineas[5]
    lista6 = lineas[6]
    lista7 = lineas[7]
    lista8 = lineas[8]
    lista9 = lineas[9]
    lista10 = lineas[10]
    lista11 = lineas[11]
    lista12 = lineas[12]
    lista13 = lineas[13]
    lista14 = lineas[14]
    
    lista1 = ''.join(lista1) #se crea un string sin comas 
    lista1 = lista1.rstrip('\n')#se quitan los saltos de linea
    lista01 = lista1.split(",")#se crea una lista separada con comas

    
    lista2 = ''.join(lista2)#se crea un string sin comas 
    lista2 = lista2.rstrip('\n')#se quitan los saltos de linea
    lista02 = lista2.split(",")#se crea una lista separada con comas


    lista3 = ''.join(lista3)#se crea un string sin comas 
    lista3 = lista3.rstrip('\n')#se quitan los saltos de linea
    lista03 = lista3.split(",")#se crea una lista separada con comas

    
    lista4 = ''.join(lista4)#se crea un string sin comas 
    lista4 = lista4.rstrip('\n')#se quitan los saltos de linea
    lista04 = lista4.split(",")#se crea una lista separada con comas

    
    lista5 = ''.join(lista5)#se crea un string sin comas 
    lista5 = lista5.rstrip('\n')#se quitan los saltos de linea
    lista05 = lista5.split(",")#se crea una lista separada con comas

    
    lista6 = ''.join(lista6)#se crea un string sin comas 
    lista6 = lista6.rstrip('\n')#se quitan los saltos de linea
    lista06 = lista6.split(",")#se crea una lista separada con comas


    lista7 = ''.join(lista7)#se crea un string sin comas 
    lista7 = lista7.rstrip('\n')#se quitan los saltos de linea
    lista07 = lista7.split(",") #se crea una lista separada con comas

    
    lista8 = ''.join(lista8)#se crea un string sin comas 
    lista8 = lista8.rstrip('\n')#se quitan los saltos de linea
    lista08 = lista8.split(",")#se crea una lista separada con comas


    lista9 = ''.join(lista9)#se crea un string sin comas 
    lista9 = lista9.rstrip('\n')#se quitan los saltos de linea
    lista09 = lista9.split(",")#se crea una lista separada con comas


    lista10 = ''.join(lista10)#se crea un string sin comas 
    lista10 = lista10.rstrip('\n')#se quitan los saltos de linea
    lista010 = lista10.split(",")#se crea una lista separada con comas


    lista11 = ''.join(lista11)#se crea un string sin comas 
    lista11 = lista11.rstrip('\n')#se quitan los saltos de linea
    lista011 = lista11.split(",")#se crea una lista separada con comas


    lista12 = ''.join(lista12)#se crea un string sin comas 
    lista12 = lista12.rstrip('\n')#se quitan los saltos de linea
    lista012 = lista12.split(",")#se crea una lista separada con comas


    lista13 = ''.join(lista13)#se crea un string sin comas 
    lista13 = lista13.rstrip('\n')#se quitan los saltos de linea
    lista013 = lista13.split(",")#se crea una lista separada con comas


    lista14 = ''.join(lista14)#se crea un string sin comas 
    lista14 = lista14.rstrip('\n')#se quitan los saltos de linea
    lista014 = lista14.split(",") #se crea una lista separada con comas


    lista = [lista01,lista02,lista03,lista04,lista05,lista06,lista07,lista08,lista09,lista010,lista011,lista012,lista013,lista014] #se crea una lista con las listas depuradas y en condiciones de operar con ellas
    
    return lista
  


  def calcular_sueldos(self,arreglo):
    self.arreglo = arreglo
   
    for i in range(14): #Se itera atraves de nuestra lista, para recorrerla elemento por elemento y calcular el sueldo
      #en cada variable se almacena la información, pero se tiene que castear de string a entero
      sueldo_base = int(self.arreglo[i][5])
      sueldo_horasextra = int(self.arreglo[i][4]) * 246.5
      sueldo_antiguedad = (2020 - int(self.arreglo[i][6]) )* .03
      sueldo_total = sueldo_base + sueldo_horasextra + sueldo_antiguedad
      print(f"El sueldo de: {self.arreglo[i][1]} {self.arreglo[i][2]} {self.arreglo[i][3]} es de: ${sueldo_total} ")

    



  def reportar_mayor_ant(self, arreglo):
    self.arreglo = arreglo
    #En este metodo, se itera y se valida lista por lista en el año de ingreso de cada empleado, regresando el de mayor antiguedad
    
    for i in range(14):
      if int(self.arreglo[i][6]) <= int(self.arreglo[0][6]):
        if int(self.arreglo[i][6]) <= int(self.arreglo[1][6]):
          if int(self.arreglo[i][6]) <= int(self.arreglo[2][6]):
            if int(self.arreglo[i][6]) <= int(self.arreglo[3][6]):
              if int(self.arreglo[i][6]) <= int(self.arreglo[4][6]):
                if int(self.arreglo[i][6]) <= int(self.arreglo[5][6]):
                  if int(self.arreglo[i][6]) <= int(self.arreglo[6][6]):
                    if int(self.arreglo[i][6]) <= int(self.arreglo[7][6]):
                      if int(self.arreglo[i][6]) <= int(self.arreglo[8][6]):
                        if int(self.arreglo[i][6]) <= int(self.arreglo[9][6]):
                          if int(self.arreglo[i][6]) <= int(self.arreglo[10][6]):
                           if int(self.arreglo[i][6]) <= int(self.arreglo[11][6]):
                             if int(self.arreglo[i][6]) <= int(self.arreglo[12][6]):
                               if int(self.arreglo[i][6]) <= int(self.arreglo[13][6]):
                                 print(f"El empleado {self.arreglo[i][1]} {self.arreglo[i][2]} {self.arreglo[i][3]} tiene la mayor antiguedad, ingreso a trabajar en el año {self.arreglo[i][6]}")                 



  def reportar_menor_ant(self, arreglo):
    self.arreglo = arreglo
    #En este metodo, se itera y se valida lista por lista en el año de ingreso de cada empleado, regresando el o los de menor antiguedad
    
    for i in range(14):
      if int(self.arreglo[i][6]) >= int(self.arreglo[0][6]):
        if int(self.arreglo[i][6]) >= int(self.arreglo[1][6]):
          if int(self.arreglo[i][6]) >= int(self.arreglo[2][6]):
            if int(self.arreglo[i][6]) >= int(self.arreglo[3][6]):
              if int(self.arreglo[i][6]) >= int(self.arreglo[4][6]):
                if int(self.arreglo[i][6]) >= int(self.arreglo[5][6]):
                  if int(self.arreglo[i][6]) >= int(self.arreglo[6][6]):
                    if int(self.arreglo[i][6]) >= int(self.arreglo[7][6]):
                      if int(self.arreglo[i][6]) >= int(self.arreglo[8][6]):
                        if int(self.arreglo[i][6]) >= int(self.arreglo[9][6]):
                          if int(self.arreglo[i][6]) >= int(self.arreglo[10][6]):
                           if int(self.arreglo[i][6]) >= int(self.arreglo[11][6]):
                             if int(self.arreglo[i][6]) >= int(self.arreglo[12][6]):
                               if int(self.arreglo[i][6]) >= int(self.arreglo[13][6]):
                                 print(f"El empleado {self.arreglo[i][1]} {self.arreglo[i][2]} {self.arreglo[i][3]} tiene la menor antiguedad, ingreso a trabajar en el año {self.arreglo[i][6]}")

Trabajadores = Sueldos()
Trabajadores.cargar_datos('junio.dat')
Trabajadores.calcular_sueldos(ejemplo.cargar_datos('junio.dat'))
Trabajadores.reportar_menor_ant(ejemplo.cargar_datos('junio.dat'))
Trabajadores.reportar_mayor_ant(ejemplo.cargar_datos('junio.dat'))
# Out:
# El sueldo de: CARLOS PEREZ CASTILLO es de: $9850.09
# El sueldo de: ANGEL GOMEZ GARRIDO es de: $10096.5
# El sueldo de: JESUS MARTIN SANTOS es de: $10343.12
# El sueldo de: DAVID JIMENEZ LOZANO es de: $10343.09
# El sueldo de: PEDRO RUIZ GUERRERO es de: $10343.09
# El sueldo de: DANIEL HERNANDEZ CANO es de: $10589.56
# El sueldo de: ALEJANDRO DIAZ PRIETO es de: $10343.06
# El sueldo de: MARIA MORENO MENDEZ es de: $10096.56
# El sueldo de: ALBERTO MUOZ CRUZ es de: $10096.59
# El sueldo de: RAFAEL ALVAREZ FLORES es de: $10343.09
# El sueldo de: FERNANDO ROMERO HERRERA es de: $10836.03
# El sueldo de: PABLO ALONSO GALLEGO es de: $10096.53
# El sueldo de: JORGE GUTIERREZ MARQUEZ es de: $10343.0
# El sueldo de: RAMON NAVARRO LEON es de: $10096.62
# El empleado ANGEL GOMEZ GARRIDO tiene la menor antiguedad, ingreso a trabajar en el año 2020
# El empleado JORGE GUTIERREZ MARQUEZ tiene la menor antiguedad, ingreso a trabajar en el año 2020
# ...
